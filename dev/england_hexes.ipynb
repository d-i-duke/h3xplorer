# %%
import geopandas as gpd
import h3.api.numpy_int as h3
from lonboard import Map, PolygonLayer, ScatterplotLayer

# %%
bottomleft = (49.970022, -5.918893)
bottomright = (51.213532, 1.632811)
topright = (58.721506, -2.206627)
topleft = (57.842317, -7.826258)
polygon = [topleft, topright, bottomright, bottomleft]
latlonpoly = h3.LatLngPoly(polygon)

# %%
refs = h3.h3shape_to_cells(latlonpoly, 5)

# %%
all_hexes = gpd.GeoDataFrame(
    {"h3_ref": refs, "geometry": [h3.cells_to_h3shape([ref]) for ref in refs]}, crs="EPSG:4326"
)
all_hexes
# Out:
#                   h3_ref                                           geometry
# 0     599424235185635327  POLYGON ((-5.16829 54.09599, -5.27507 54.04482...
# 1     599423694019756031  POLYGON ((0.03571 51.11547, 0.13753 51.16359, ...
# 2     599424955666399231  POLYGON ((-0.85212 51.46223, -0.8297 51.37644,...
# 3     599424414500519935  POLYGON ((-3.32952 54.55876, -3.30141 54.47504...
# 4     599421529356238847  POLYGON ((-4.24214 57.77925, -4.12699 57.82572...
# ...                  ...                                                ...
# 1715  599423409478172671  POLYGON ((-0.32851 54.35336, -0.198 54.31546, ...
# 1716  599425032975810559  POLYGON ((-4.41553 52.67359, -4.38651 52.58827...
# 1717  599424491809931263  POLYGON ((-5.95064 54.81365, -5.80975 54.78128...
# 1718  599408986977992703  POLYGON ((-4.96207 51.08385, -5.06336 51.03022...
# 1719  599423950644051967  POLYGON ((0.92083 52.18577, 0.94052 52.10081, ...
#
# [1720 rows x 2 columns]

# %%
points = gpd.GeoDataFrame(
    {"ref": [1, 2, 3, 4, 5]},
    geometry=gpd.points_from_xy(
        x=[-3.448079, -2.001428, -0.494362, -0.128329, -2.001375],
        y=[51.689821, 52.597808, 53.487243, 51.503992, 51.249166],
        crs="EPSG:4326",
    ),
)

# %%
hex_layer = PolygonLayer.from_geopandas(all_hexes)
hex_layer.get_fill_color = [255, 0, 0, 100]
hex_layer.get_line_color = [255, 0, 0, 255]
hex_layer.line_width_min_pixels = 0.5
hex_layer.line_width_max_pixels = 5
point_layer = ScatterplotLayer.from_geopandas(points)
point_layer.get_radius = 500
m = Map([hex_layer, point_layer])
m
# Out:
# Map(custom_attribution='', layers=(PolygonLayer(get_fill_color=[255, 0, 0, 100], get_line_color=[255, 0, 0, 25…
